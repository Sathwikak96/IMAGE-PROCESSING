# %%
import matplotlib.pyplot as plt
# %matplotlib inline
 

from skimage import data,filters


image = data.coins()
# ... or any other NumPy array!
edges = filters.sobel(image)
plt.imshow(edges, cmap='gray')

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline

 
image = data.camera()
type(image)


np.ndarray #Image is a numpy array
mask = image < 87
image[mask]=255
plt.imshow(image, cmap='gray')

# %%
from scipy import misc,ndimage
import cv2
img=cv2.imread('w2.jpg')
face = misc.face()
blurred_face = ndimage.gaussian_filter(face, sigma=3)
very_blurred = ndimage.gaussian_filter(face, sigma=5)


#Results
plt.imshow(img)

# %%
from PIL import Image, ImageFilter
#Read image
im = Image.open( 'w2.jpg' )
#Display image
im.show()
 

from PIL import ImageEnhance
enh = ImageEnhance.Contrast(im)
enh.enhance(1.8).show("100% more contrast")

# %%
from SimpleCV import Camera
# Initialize the camera
cam = Camera()
# Loop to continuously get images
while True:
    # Get Image from camera
    img = cam.getImage()
    # Make image black and white
    img = img.binarize()
    # Draw the text "Hello World" on image
    img.drawText("Hello World!")
    # Show the image
    img.show()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\mca\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-5-3df6ade5e093>", line 1, in <module>
#     from SimpleCV import Camera
#
#   File "C:\Users\mca\anaconda3\lib\site-packages\SimpleCV\__init__.py", line 3, in <module>
#     from SimpleCV.base import *
#
#   File "C:\Users\mca\anaconda3\lib\site-packages\SimpleCV\base.py", line 139
#     print 'unit test'
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('unit test')?

# %%
import numpy as np
import mahotas as mh
import pylab
img = mh.imread('p1.jpg')
T_otsu = mh.thresholding.otsu(img)
seeds,_= mh.label(img > T_otsu)
labeled = mh.cwatershed(img.max() - img, seeds)

pylab.imshow(labeled)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# importing required libraries
import numpy as np
import mahotas as mh
from pylab import imshow, show
 
# loading image
img5 = mh.imread('p1.jpg')
 
# showing the original image
imshow(img5)
show()

# %%
from pgmagick.api import Image

img = Image((300, 200), 'red')
img.write('w2.jpg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-53d0dd64a170> in <module>
# ----> 1 from pgmagick.api import Image
#       2
#       3 img = Image((300, 200), 'red')
#       4 img.write('w2.jpg')
#
# ModuleNotFoundError: No module named 'pgmagick'

# %%
from pgmagick import Image

#Include full path to the input image
img = Image('w2.jpg')
img.filterType(FilterTypes.SincFilter)
img.resize('150x150')
img.write('x.jpg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-bec1ff0c5446> in <module>
# ----> 1 from pgmagick import Image
#       2
#       3 #Include full path to the input image
#       4 img = Image('w2.jpg')
#       5 img.filterType(FilterTypes.SincFilter)
#
# ModuleNotFoundError: No module named 'pgmagick'
