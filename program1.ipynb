# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\central computer lab\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\central computer lab\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
img=cv2.imread('F1.jfif',0)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.image as mping
import matplotlib.pyplot as plt
img=mping.imread('F1.jfif')
plt.imshow(img)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import cv2
from PIL import Image
img=Image.open('F1.jfif')
img=img.rotate(180)
img.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import ImageColor
img1=ImageColor.getrgb("yellow")
print(img1)
img2=ImageColor.getrgb("red")
print(img2)                           
img3=ImageColor.getrgb("pink")
print(img3)
# Out:
# (255, 255, 0)
# (255, 0, 0)
# (255, 192, 203)

# %%
from PIL import Image
img=Image.new('RGB',(200,400),(255,0,0))
img.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('F1.jfif')
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img)
plt.show()

# %%
from PIL import Image
image=Image.open('F1.jfif')
print("Filename:",image.filename)
print("Format:",image.format)
print("Mode:",image.mode)
print("Size:",image.size)
print("Width:",image.width)
print("Height:",image.height)
image.close()
# Out:
# Filename: F1.jfif
# Format: JPEG
# Mode: RGB
# Size: (275, 183)
# Width: 275
# Height: 183
